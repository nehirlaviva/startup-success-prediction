# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import shap
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from utils import load_and_clean_data, calculate_momentum_scores, run_model_experiment

# Initialize SHAP for Jupyter Notebook
shap.initjs()
# Set standard plotting style for thesis
sns.set_style("whitegrid")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
print("--- STARTING THESIS PIPELINE ---")

# 1. Load Data
df_train, df_full = load_and_clean_data('yc_companies.csv')

# 2. Calculate Scores (Catching BOTH the dataframe and the dictionary)
df_scored, yearly_word_scores = calculate_momentum_scores(df_train, df_full)

# 3. Train Models
trained_rf, trained_xgb, X_test, y_test, metrics = run_model_experiment(df_scored)

# Print Final F1 Scores
print("\n--- FINAL MODEL METRICS ---")
print(f"Random Forest - Baseline: {metrics['Random Forest']['Baseline']:.4f} | Augmented: {metrics['Random Forest']['Augmented']:.4f}")
print(f"XGBoost       - Baseline: {metrics['XGBoost']['Baseline']:.4f} | Augmented: {metrics['XGBoost']['Augmented']:.4f}")
# Out:
# --- STARTING THESIS PIPELINE ---
# Loading and Cleaning Data...
# Pre-processing text: Combining, Cleaning, and Lemmatizing...
# Training Models...
# Models Trained Successfully!
#
# --- FINAL MODEL METRICS ---
# Random Forest - Baseline: 0.5778 | Augmented: 0.5993
# XGBoost       - Baseline: 0.5703 | Augmented: 0.5703

# %%
# Create the validation table
df_scored['Score_Rounded'] = df_scored['Market_Signal_Score'].round().astype(int)

validation_table = df_scored.groupby('Score_Rounded').agg(
    Total_Startups=('Target', 'count'),
    Successful_Startups=('Target', 'sum')
)

validation_table['Success_Rate_%'] = (validation_table['Successful_Startups'] / validation_table['Total_Startups'] * 100).round(2)

print("--- THE TRUTH TABLE: Success Rate vs. Market Signal ---")
print(validation_table)

top_score_rate = validation_table.loc[3, 'Success_Rate_%'] if 3 in validation_table.index else 0
bottom_score_rate = validation_table.loc[0, 'Success_Rate_%'] if 0 in validation_table.index else 0

print(f"\nAnalysis:")
print(f"Success rate for Stagnant Markets (Score 0): ~{bottom_score_rate}%")
print(f"Success rate for Peak Momentum Pioneers (Score 3): ~{top_score_rate}%")
# Out:
# --- THE TRUTH TABLE: Success Rate vs. Market Signal ---
#                Total_Startups  Successful_Startups  Success_Rate_%
# Score_Rounded
# 0                         162                   35           21.60
# 1                         147                   64           43.54
# 2                         934                  424           45.40
# 3                         223                   92           41.26
#
# Analysis:
# Success rate for Stagnant Markets (Score 0): ~21.6%
# Success rate for Peak Momentum Pioneers (Score 3): ~41.26%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("--- RQ ANALYSIS: DEEP DIVE INTO 'WEAK SIGNAL' (SCORE 3) PIONEERS ---")

# 1. Isolate the Weak Signal Startups
weak_signal_df = df_scored[df_scored['Score_Rounded'] == 3].copy()

if weak_signal_df.empty:
    print("Warning: No Weak Signal startups found. Please check scoring thresholds.")
else:
    total_weak = len(weak_signal_df)
    successful_weak = len(weak_signal_df[weak_signal_df['Target'] == 1])
    failed_weak = len(weak_signal_df[weak_signal_df['Target'] == 0])
    
    print(f"Total 'Weak Signal' Startups Analyzed: {total_weak}")
    print(f"Successful Exits: {successful_weak} | Failures/Inactive: {failed_weak}\n")
    
    # 2. Statistical Comparison of Operational Characteristics
    operational_features = ['team_size', 'founder_count', 'has_website', 'has_logo']
    
    # Group by Target (0 = Fail, 1 = Success) and calculate the mean for each feature
    summary_df = weak_signal_df.groupby('Target')[operational_features].mean().round(2)
    summary_df.index = ['Failed (0)', 'Successful (1)']
    
    print("--- AVERAGE OPERATIONAL METRICS FOR WEAK SIGNAL STARTUPS ---")
    print(summary_df)
    print("\n")

    # 3. Visualizing Key Differentiators (Team Size & Founder Count)
    plt.figure(figsize=(14, 5))
    
    # Boxplot for Team Size
    plt.subplot(1, 2, 1)
    sns.boxplot(data=weak_signal_df, x='Target', y='team_size', palette=['#FF6B6B', '#4ECDC4'])
    plt.title('Team Size Distribution in Weak Signal Markets', fontsize=12, fontweight='bold')
    plt.xticks([0, 1], ['Failed', 'Successful'])
    plt.ylabel('Team Size')
    
    # Boxplot for Founder Count
    plt.subplot(1, 2, 2)
    sns.boxplot(data=weak_signal_df, x='Target', y='founder_count', palette=['#FF6B6B', '#4ECDC4'])
    plt.title('Founder Count Distribution in Weak Signal Markets', fontsize=12, fontweight='bold')
    plt.xticks([0, 1], ['Failed', 'Successful'])
    plt.ylabel('Number of Founders')
    
    plt.tight_layout()
    plt.show()

    # 4. Sector-Specific Analysis: Where do Pioneers succeed most?
    print("--- SECTOR SPECIFIC SUCCESS RATES FOR WEAK SIGNALS ---")
    
    # To keep the plot readable, let's filter to the Top 8 industries with the most weak signal startups
    top_industries = weak_signal_df['industry'].value_counts().head(8).index
    sector_df = weak_signal_df[weak_signal_df['industry'].isin(top_industries)]
    
    # Calculate success rates per industry
    sector_success = sector_df.groupby('industry')['Target'].agg(['count', 'mean']).reset_index()
    sector_success.rename(columns={'count': 'Total_Startups', 'mean': 'Success_Rate'}, inplace=True)
    sector_success['Success_Rate'] = (sector_success['Success_Rate'] * 100).round(1)
    sector_success = sector_success.sort_values('Success_Rate', ascending=False)
    
    print(sector_success.to_string(index=False))
    
    # Plotting Sector Success
    plt.figure(figsize=(12, 6))
    sns.barplot(data=sector_success, x='industry', y='Success_Rate', palette='viridis')
    plt.title('Success Rate of "Weak Signal" Startups by Top Industries', fontsize=14, fontweight='bold')
    plt.ylabel('Success Rate (%)')
    plt.xlabel('Industry Sector')
    plt.xticks(rotation=45, ha='right')
    
    # Add percentage labels on top of the bars
    for i, rate in enumerate(sector_success['Success_Rate']):
        plt.text(i, rate + 1, f"{rate}%", ha='center', fontsize=10)
        
    plt.tight_layout()
    plt.show()
# Out:
# --- RQ ANALYSIS: DEEP DIVE INTO 'WEAK SIGNAL' (SCORE 3) PIONEERS ---
# Total 'Weak Signal' Startups Analyzed: 223
# Successful Exits: 92 | Failures/Inactive: 131
#
# --- AVERAGE OPERATIONAL METRICS FOR WEAK SIGNAL STARTUPS ---
#                 team_size  founder_count  has_website  has_logo
# Failed (0)           7.18           1.95          1.0      0.79
# Successful (1)      28.84           1.90          1.0      0.80
# --- SECTOR SPECIFIC SUCCESS RATES FOR WEAK SIGNALS ---
#                                             industry  Total_Startups  Success_Rate
#                                   B2B,Infrastructure              10          50.0
#                                           B2B,Retail              12          50.0
#                             Fintech,Consumer Finance              10          50.0
# Real Estate and Construction,Housing and Real Estate               9          44.4
#                  B2B,Engineering, Product and Design              23          43.5
# ...

# %%
# Calculate Global SHAP values for Random Forest (Champion Model)
explainer_rf = shap.TreeExplainer(trained_rf)
shap_values_rf = explainer_rf.shap_values(X_test)

if isinstance(shap_values_rf, list):
    shap_values_success = shap_values_rf[1]
else:
    shap_values_success = shap_values_rf[:, :, 1]

print("--- GLOBAL FEATURE IMPORTANCE (INVESTOR RUBRIC) ---")
shap.summary_plot(shap_values_success, X_test, plot_type="bar", show=False)
plt.title("Random Forest: Global Predictors of Startup Success")
plt.tight_layout()
plt.show()
# Out:
# --- GLOBAL FEATURE IMPORTANCE (INVESTOR RUBRIC) ---

# %%
# Create a sample to make SHAP calculations run faster
X_test_sample = X_test.sample(n=min(200, len(X_test)), random_state=42)

# Calculate SHAP values specifically for XGBoost
explainer_xgb = shap.TreeExplainer(trained_xgb)
shap_values_xgb = explainer_xgb.shap_values(X_test_sample)

print("--- SHAP DEPENDENCE PLOT: Market Signal vs Team Size ---")
shap.dependence_plot(
    "Market_Signal_Score", 
    shap_values_xgb, 
    X_test_sample, 
    interaction_index="team_size" 
)
# Out:
# --- SHAP DEPENDENCE PLOT: Market Signal vs Team Size ---

# %%
# Initialize Explainer object needed specifically for Waterfall plots
explainer_obj = shap.Explainer(trained_xgb, X_test_sample)
shap_values_sample = explainer_obj(X_test_sample)

# Find a successful startup
success_indices = np.where(y_test.loc[X_test_sample.index] == 1)[0]
# Find an inactive startup that had a high trend score (The failed pioneer)
failure_indices = np.where((y_test.loc[X_test_sample.index] == 0) & (X_test_sample['Market_Signal_Score'] > 1.5))[0]

if len(success_indices) > 0:
    idx = success_indices[0]
    startup_name = df_scored.loc[X_test_sample.index[idx], 'name']
    print(f"--- LOCAL CASE STUDY 1: Why did {startup_name} succeed? ---")
    
    plt.figure() # Clears the canvas to prevent overlaps
    # Handle the shape output dynamically based on SHAP version
    if len(shap_values_sample.shape) == 3:
        shap.plots.waterfall(shap_values_sample[idx, :, 1])
    else:
        shap.plots.waterfall(shap_values_sample[idx])
    plt.show()

if len(failure_indices) > 0:
    idx = failure_indices[0]
    startup_name = df_scored.loc[X_test_sample.index[idx], 'name']
    print(f"\n--- LOCAL CASE STUDY 2: Why did {startup_name} fail despite a strong market signal? ---")
    
    plt.figure() # Clears the canvas to prevent overlaps
    if len(shap_values_sample.shape) == 3:
        shap.plots.waterfall(shap_values_sample[idx, :, 1])
    else:
        shap.plots.waterfall(shap_values_sample[idx])
    plt.show()
# Out:
# --- LOCAL CASE STUDY 1: Why did Okay succeed? ---
# --- LOCAL CASE STUDY 2: Why did SpringWit fail despite a strong market signal? ---

# %%
from sklearn.feature_extraction.text import CountVectorizer

# 1. Ensure the data is ready
analysis_year = df_scored['batch_year'].max()
scores_dict = yearly_word_scores.get(analysis_year, {})

# 2. Extract and count words/bigrams for the latest year matching our dictionary
corpus = df_scored[df_scored['batch_year'] == analysis_year]['combined_text'].dropna()

if not corpus.empty and scores_dict:
    # Use CountVectorizer locked to the exact phrases in our scores_dict
    vec = CountVectorizer(ngram_range=(1, 2), vocabulary=scores_dict.keys())
    X_counts = vec.fit_transform(corpus)
    
    # Map the phrases back to their total counts
    word_counts = dict(zip(vec.get_feature_names_out(), X_counts.sum(axis=0).A1))
else:
    word_counts = {}

# 3. Categorize the counted words
data = []
for word, count in word_counts.items():
    if count > 0: # Only include words that actually appeared
        score = scores_dict[word]
        if score == 3: cat = "Weak Signal (Pioneer)"
        elif score == 2: cat = "Strong Signal (Early Trend)"
        elif score == 1: cat = "Stable (Mainstream)"
        else: cat = "Stagnant (Niche)"
            
        data.append({'Word': word, 'Count': count, 'Score': score, 'Category': cat})

df_freq = pd.DataFrame(data)

# 4. Plotting
plt.figure(figsize=(16, 12))
colors = ['#808080', '#4169E1', '#FFA500', '#FF4500']

for i in range(4):
    plt.subplot(2, 2, i+1)
    subset = df_freq[df_freq['Score'] == i].sort_values(by='Count', ascending=False).head(10)
    if not subset.empty:
        sns.barplot(data=subset, x='Count', y='Word', color=colors[i])
        plt.title(f"Top {subset['Category'].iloc[0]} Keywords", fontsize=14, fontweight='bold')
    else:
        plt.text(0.5, 0.5, 'No data for this category', ha='center', va='center')

plt.suptitle(f"Frequency Analysis of Market Signals: YC Batch {analysis_year}", fontsize=20, y=1.02)
plt.tight_layout()
plt.show()

# Print summary for thesis text
print(f"--- THESIS SUMMARY: WEAK SIGNALS DETECTED IN {analysis_year} ---")
weak_signals = df_freq[df_freq['Score'] == 3].sort_values(by='Count', ascending=False)
if not weak_signals.empty:
    print(f"The top 'Weak Signals' driving the Score 3 category were: {', '.join(weak_signals['Word'].head(8).tolist())}")
# Out:
# --- THESIS SUMMARY: WEAK SIGNALS DETECTED IN 2024 ---
# The top 'Weak Signals' driving the Score 3 category were: computing infrastructure, consumer gaming, document workflow, gaming ai, insurance ai, insurance broker
